# %% [markdown]
# # Importaciones

# %%
# !pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: absl-py==1.2.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: asttokens==2.0.8 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: attrs==22.1.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 4)) (22.1.0)
# Requirement already satisfied: backcall==0.2.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: cachetools==5.2.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: certifi==2022.9.14 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 7)) (2022.9.14)
# Requirement already satisfied: charset-normalizer==2.1.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: cycler==0.11.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 12)) (0.4)
# Requirement already satisfied: executing==1.0.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: flatbuffers==2.0.7 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: fonttools==4.37.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 15)) (4.37.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 16)) (0.4.0)
# Requirement already satisfied: google-auth==2.11.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 17)) (2.11.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: grpcio==1.48.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 20)) (1.48.1)
# Requirement already satisfied: h5py==3.7.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 21)) (3.7.0)
# Requirement already satisfied: idna==3.4 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 22)) (3.4)
# Requirement already satisfied: importlib-metadata==4.12.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 23)) (4.12.0)
# Requirement already satisfied: ipykernel==6.15.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 24)) (6.15.3)
# Requirement already satisfied: ipynb==0.5.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 25)) (0.5.1)
# Requirement already satisfied: ipython==8.5.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 26)) (8.5.0)
# Requirement already satisfied: jedi==0.18.1 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 27)) (0.18.1)
# Requirement already satisfied: joblib==1.1.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 28)) (1.1.0)
# Requirement already satisfied: jupyter-core==4.11.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 29)) (4.11.1)
# Requirement already satisfied: jupyter_client==7.3.5 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 30)) (7.3.5)
# Requirement already satisfied: keras==2.10.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 31)) (2.10.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 32)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 33)) (1.4.4)
# Requirement already satisfied: libclang==14.0.6 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 34)) (14.0.6)
# Requirement already satisfied: Markdown==3.4.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 35)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.1.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 36)) (2.1.1)
# Requirement already satisfied: matplotlib==3.5.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 37)) (3.5.3)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 38)) (0.1.6)
# Requirement already satisfied: mediapipe==0.8.11 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 39)) (0.8.11)
# Requirement already satisfied: nest-asyncio==1.5.5 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 40)) (1.5.5)
# Requirement already satisfied: numpy==1.23.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 41)) (1.23.3)
# Requirement already satisfied: oauthlib==3.2.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 42)) (3.2.1)
# Requirement already satisfied: opencv-contrib-python==4.6.0.66 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 43)) (4.6.0.66)
# Requirement already satisfied: opencv-python==4.6.0.66 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 44)) (4.6.0.66)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 45)) (3.3.0)
# Requirement already satisfied: packaging==21.3 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 46)) (21.3)
# Requirement already satisfied: parso==0.8.3 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 47)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 48)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 49)) (0.7.5)
# Requirement already satisfied: Pillow==9.2.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 50)) (9.2.0)
# Requirement already satisfied: prompt-toolkit==3.0.31 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 51)) (3.0.31)
# Requirement already satisfied: protobuf==3.19.5 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 52)) (3.19.5)
# Requirement already satisfied: psutil==5.9.2 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 53)) (5.9.2)
# Requirement already satisfied: ptyprocess==0.7.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 54)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 55)) (0.2.2)
# Requirement already satisfied: pyasn1==0.4.8 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 56)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 57)) (0.2.8)
# Requirement already satisfied: Pygments==2.13.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 58)) (2.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 59)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 60)) (2.8.2)
# Requirement already satisfied: pyzmq==23.2.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 61)) (23.2.1)
# Requirement already satisfied: requests==2.28.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 62)) (2.28.1)
# Requirement already satisfied: requests-oauthlib==1.3.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 63)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 64)) (4.9)
# Requirement already satisfied: scikit-learn==1.1.2 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 65)) (1.1.2)
# Requirement already satisfied: scipy==1.9.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 66)) (1.9.1)
# Requirement already satisfied: six==1.16.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 67)) (1.16.0)
# Requirement already satisfied: sklearn==0.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 68)) (0.0)
# Requirement already satisfied: stack-data==0.5.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 69)) (0.5.0)
# Requirement already satisfied: tensorboard==2.10.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 70)) (2.10.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 71)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 72)) (1.8.1)
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 73)) (2.10.0)
# Requirement already satisfied: tensorflow-estimator==2.10.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 74)) (2.10.0)
# Requirement already satisfied: tensorflow-gpu==2.10.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 75)) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.27.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 76)) (0.27.0)
# Requirement already satisfied: termcolor==2.0.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 77)) (2.0.1)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 78)) (3.1.0)
# Requirement already satisfied: tornado==6.2 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 79)) (6.2)
# Requirement already satisfied: traitlets==5.4.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 80)) (5.4.0)
# Requirement already satisfied: typing_extensions==4.3.0 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 81)) (4.3.0)
# Requirement already satisfied: urllib3==1.26.12 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 82)) (1.26.12)
# Requirement already satisfied: wcwidth==0.2.5 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 83)) (0.2.5)
# Requirement already satisfied: Werkzeug==2.2.2 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 84)) (2.2.2)
# Requirement already satisfied: wrapt==1.14.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 85)) (1.14.1)
# Requirement already satisfied: zipp==3.8.1 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from -r ../requirements.txt (line 86)) (3.8.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse==1.6.3->-r ../requirements.txt (line 3)) (0.37.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython==8.5.0->-r ../requirements.txt (line 26)) (0.4.4)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core==4.11.1->-r ../requirements.txt (line 29)) (302)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard==2.10.0->-r ../requirements.txt (line 70)) (61.2.0)

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nicole dosman\appdata\roaming\python\python39\site-packages (from opencv-python) (1.23.3)

# %%
import os
import time
from pathlib import Path

import cv2
import numpy as np
import mediapipe as mp
from matplotlib import pyplot as plt

from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       2 import time
#       3 from pathlib import Path
# ----> 5 import cv2
#       6 import numpy as np
#       7 import mediapipe as mp
#
# ModuleNotFoundError: No module named 'cv2'

# %%
from ipynb.fs.full.functions import get_mp_resources
from ipynb.fs.full.functions import extract_keypoints
from ipynb.fs.full.functions import mediapipe_detection
from ipynb.fs.full.functions import draw_styled_landmarks
from ipynb.fs.full.nb03_prepare_collection import N_SEQ, SEQ_LEN
from ipynb.fs.full.nb03_prepare_collection import DATA_PATH, ABC, EXPRESSIONS

# %% [markdown]
# # Importar modelo y datos

# %%
MODELS_PATH = DATA_PATH.parent.parent.joinpath("models").resolve()
TARGET_PATH = DATA_PATH.parent.joinpath("processed")

# %%
X_train = np.load(TARGET_PATH.joinpath("X_train.npy"))
X_test  = np.load(TARGET_PATH.joinpath("X_test.npy"))
y_train = np.load(TARGET_PATH.joinpath("y_train.npy"))
y_test  = np.load(TARGET_PATH.joinpath("y_test.npy"))

# %%
model = Sequential()
model.add(LSTM(64, return_sequences = True, activation = "relu", input_shape=(30,1662)))
model.add(LSTM(128, return_sequences = True, activation = "relu"))
model.add(LSTM(64, return_sequences = False, activation = "relu"))
model.add(Dense(64, activation = "relu"))
model.add(Dense(32, activation = "relu"))
model.add(Dense(len(EXPRESSIONS), activation = "softmax"))
model.compile(
    optimizer="Adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"]
)

# %%
model.load_weights(f"{MODELS_PATH}/expresions.h5")

# %% [markdown]
# # Pruebas en tiempo real

# %%
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245)]
def prob_vizualization(res, input_frame, colors = colors):
    output_frame = input_frame.copy()
    for n, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+n*40), (int(prob*100), 90+n*40), colors[n], -1)
        cv2.putText(
            output_frame, EXPRESSIONS[n], (0, 85+n*40),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA
        )
    return output_frame

# %%
def start_real_time_detection(mp_holistic, mp_drawing):
    sequence = []
    sentence = []
    threshold = 0.7
    captura = cv2.VideoCapture(0)

    # Acceso/configuración al modulo de mediapipe
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while captura.isOpened():
            # Lectura via camara
            _, frame = captura.read()

            # Realizar detecciones
            image, results = mediapipe_detection(frame, holistic)

            # Dibujar landmarks
            draw_styled_landmarks(image, results, mp_holistic, mp_drawing)

            image = cv2.flip(image, 1)

            # Logica de predicción
            _, keypoints = extract_keypoints(results)
            # sequence.insert(0, keypoints)
            # sequence = sequence[:30]
            sequence.append(keypoints)
            sequence = sequence[-30:]


            if len(sequence) == 30:
                res = model.predict(np.expand_dims(sequence, axis=0))[0]

                # Logica de visualización
                if res[np.argmax(res)] > threshold:
                    if sentence:
                        if EXPRESSIONS[np.argmax(res)] != sentence[-1]:
                            sentence.append(EXPRESSIONS[np.argmax(res)])
                    else:
                        sentence.append(EXPRESSIONS[np.argmax(res)])

                if len(sequence) > 5:
                    sentence = sentence[-5:]

                image = prob_vizualization(res, image)


            # Mostrar en pantalla
            cv2.imshow('OpenCV', image)

            # Salida
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
        captura.release()
        cv2.destroyAllWindows()

# %%
mp_holistic, mp_drawing = get_mp_resources()

# %%
start_real_time_detection(mp_holistic, mp_drawing)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
